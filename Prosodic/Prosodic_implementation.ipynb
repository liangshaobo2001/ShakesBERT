# %%
# Processing Shakespeare sonnets

import prosodic as p

# p.config['print_to_screen'] = 1

p.config['en_TTS_ENGINE']='espeak'
# print(p.config['en_TTS_ENGINE'])

p.config['print_to_screen']=1
# meter_name = 'iambic_pentameter'
meter_name = 'default_english'
meter = p.get_meter(meter_name)

# data_name = "poems_train_"
# data_name = "sonnets_train_"
data_name = "shakestrain_train_"
# data_name = "testSample_train_"

sonnets_thousand_lines = 42
poems_thousand_lines = 3552


input_file = open(f"./train_data_processed/{data_name}lines.txt", "r", encoding = "utf8")
input_text = input_file.read()

print(len(input_text))
data = p.Text(input_text)

data.parse(meter=meter)

with open(f"./train_data_prosodic/{data_name}prosodic.txt",'w') as f:
    for line in data.bestParses():
        print(line, file=f)




# input_file = open(f"./train_data_processed/{data_name}lines.txt", "r")

# with open(f"./train_data_prosodic/{data_name}prosodic.txt",'w') as f:
#     while True:
#         input_line = input_file.readline()
#         if not input_line:
#             break
#         data = p.Text(input_line)
#         data.parse(meter=meter)
#         print(data.bestParses(), file=f)



f.close()

# %%
# Processing sonnets

import prosodic as p

# p.config['print_to_screen'] = 1

p.config['en_TTS_ENGINE']='espeak'
# print(p.config['en_TTS_ENGINE'])

p.config['print_to_screen']=0
# meter_name = 'iambic_pentameter'
meter_name = 'default_english'
meter = p.get_meter(meter_name)

# data_name = "poems_train_"
data_name = "sonnets_train_"
# data_name = "shakestrain_train_"
# data_name = "testSample_train_"

sonnets_thousand_lines = 42
poems_thousand_lines = 3552

for i in range(sonnets_thousand_lines):
    print(f"converting {i+1} thousand lines")
    input_file = open(f"./train_data_processed/sonnets_train_split/sonnets_train_lines_{i + 1}.txt", "r", encoding = "utf8")
    input_text = input_file.read()

    data = p.Text(input_text)

    data.parse(meter=meter)

    with open(f"./train_data_prosodic/sonnets_train_split/sonnets_train_prosodic_{i + 1}.txt",'x', encoding = "utf8") as f:
        for line in data.bestParses():
            print(line, file=f)




    # input_file = open(f"./train_data_processed/{data_name}lines.txt", "r")

    # with open(f"./train_data_prosodic/{data_name}prosodic.txt",'w') as f:
    #     while True:
    #         input_line = input_file.readline()
    #         if not input_line:
    #             break
    #         data = p.Text(input_line)
    #         data.parse(meter=meter)
    #         print(data.bestParses(), file=f)



    f.close()
# Out:
# converting 1 thousand lines
# converting 2 thousand lines
# converting 3 thousand lines
# converting 4 thousand lines
# !! Time limit (30s) elapsed in trying to parse line: i am if she is gone and when she goes i know not why for that is a strange art
# converting 5 thousand lines
# converting 6 thousand lines
# converting 7 thousand lines
# converting 8 thousand lines
# !! Time limit (30s) elapsed in trying to parse line: or art effect what he hath brought to pass it is not like he naked me hath seen
# !! Time limit (30s) elapsed in trying to parse line: i ll burn i ll freeze but you shall be recovered good god would beauty mark now she is crased
# !! Time limit (30s) elapsed in trying to parse line: and i oh would i might or would she meant it should hery a love who now in heart lament it
# converting 9 thousand lines
# !! Time limit (30s) elapsed in trying to parse line: be all stars adverse toward her that come forth nightly by day all hours till all have ceased
# ...

# %%
# Processing poems

import prosodic as p

# p.config['print_to_screen'] = 1

p.config['en_TTS_ENGINE']='espeak'
# print(p.config['en_TTS_ENGINE'])

p.config['print_to_screen']=0
# meter_name = 'iambic_pentameter'
meter_name = 'default_english'
meter = p.get_meter(meter_name)

# data_name = "poems_train_"
# data_name = "sonnets_train_"
# data_name = "shakestrain_train_"
# data_name = "testSample_train_"

sonnets_thousand_lines = 42
poems_thousand_lines = 3552

for i in range(poems_thousand_lines):
    print(f"converting {i+1} thousand lines")
    input_file = open(f"./train_data_processed/poems_train_split/poems_train_lines_{i + 1}.txt", "r", encoding = "utf8")
    input_text = input_file.read()

    data = p.Text(input_text)

    data.parse(meter=meter)

    with open(f"./train_data_prosodic/poems_train_split/poems_train_prosodic_{i + 1}.txt",'x', encoding = "utf8") as f:
        for line in data.bestParses():
            print(line, file=f)




    # input_file = open(f"./train_data_processed/{data_name}lines.txt", "r")

    # with open(f"./train_data_prosodic/{data_name}prosodic.txt",'w') as f:
    #     while True:
    #         input_line = input_file.readline()
    #         if not input_line:
    #             break
    #         data = p.Text(input_line)
    #         data.parse(meter=meter)
    #         print(data.bestParses(), file=f)



    f.close()
# Out:
# converting 1 thousand lines
# !! Time limit (30s) elapsed in trying to parse line: we know the world is false not what is true yet we think on knowing we ne er shall know
# !! Time limit (30s) elapsed in trying to parse line: i ll saddle up my creamy colt and he shall carry you my creamy colt who will not bolt who does not shy nor kick
# !! Time limit (30s) elapsed in trying to parse line: some day i might be replied the blue gum if i do n't grow too old there is some fine timber in me yet
# !! Time limit (30s) elapsed in trying to parse line: oh that s only his way of putting it answered the blue gum kindly he does n't really mean it you know he wants a change that s all
# !! Time limit (30s) elapsed in trying to parse line: it is not an early riser but it has a snubbish nose if you snear at it or scold it it will scuttle off in shame
# ...
